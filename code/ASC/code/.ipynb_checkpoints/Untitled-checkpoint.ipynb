# %%
from Learn import Power
import pickle
import pandas as pd
import seaborn as sns

# %%
f = open('./sp_powerlist_ranking', 'rb')
speech = pd.read_csv('../statistics/speech.csv')
music = pd.read_csv('../statistics/music.csv')

# %%
em_powerlist = pickle.load(f)

# %%
index = 2
print(em_powerlist[index].name_)
sns.distplot(speech[em_powerlist[index].name_], color="blue")
sns.distplot(music[em_powerlist[index].name_], color="red")
# Out:
# mfcc_std_2
# /home/guwenqi/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
